# %%
import kagglehub

path = kagglehub.dataset_download("aadeshkoirala/mnist-784")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/aadeshkoirala/mnist-784?dataset_version_number=1...
# 100%|█████████████████████████████████████████████████████████████████████████████| 15.2M/15.2M [00:02<00:00, 7.91MB/s]
# Extracting files...
# Path to dataset files: C:\Users\nodos\.cache\kagglehub\datasets\aadeshkoirala\mnist-784\versions\1

# %%
from git import Repo
repo_url = 'https://github.com/Jakobovski/free-spoken-digit-dataset'
local_dir = './free-spoken-digit-dataset'
Repo.clone_from(repo_url, local_dir)
# Out:
# <git.repo.base.Repo 'C:\\Users\\nodos\\Desktop\\ДИПЛОМ\\free-spoken-digit-dataset\\.git'>

# %%
# !apt-get install imagemagick
# !pip install matplotlib==3.9.2
# !pip install pandas==2.2.2
# !pip install numpy==1.26.4
# !pip install librosa==0.10.2.post1
# !pip install brian2==2.7.1
# !pip install soundfile==0.12.1
# !pip install ipython==8.27.0
# Out:
# "apt-get" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# Collecting librosa==0.10.2.post1
#   Using cached librosa-0.10.2.post1-py3-none-any.whl (260 kB)
# Collecting soxr>=0.3.2
#   Downloading soxr-0.5.0.post1-cp39-cp39-win_amd64.whl (167 kB)
# Collecting lazy-loader>=0.1
#   Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (5.1.1)
# Collecting audioread>=2.1.9
#   Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (4.10.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (1.5.2)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (1.24.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (1.12.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\nodos\appdata\roaming\python\python39\site-packages (from librosa==0.10.2.post1) (1.2.0)
# Collecting soundfile>=0.12.1
#   Using cached soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
# Collecting pooch>=1.1
#   Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Requirement already satisfied: numba>=0.51.0 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (0.55.1)
# Requirement already satisfied: msgpack>=1.0 in c:\users\nodos\anaconda3\lib\site-packages (from librosa==0.10.2.post1) (1.0.2)
# Requirement already satisfied: packaging in c:\users\nodos\anaconda3\lib\site-packages (from lazy-loader>=0.1->librosa==0.10.2.post1) (23.2)
# Requirement already satisfied: setuptools in c:\users\nodos\anaconda3\lib\site-packages (from numba>=0.51.0->librosa==0.10.2.post1) (72.2.0)
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3
#   Using cached numpy-1.21.6-cp39-cp39-win_amd64.whl (14.0 MB)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in c:\users\nodos\anaconda3\lib\site-packages (from numba>=0.51.0->librosa==0.10.2.post1) (0.38.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\nodos\anaconda3\lib\site-packages (from pooch>=1.1->librosa==0.10.2.post1) (4.2.2)
# Requirement already satisfied: requests>=2.19.0 in c:\users\nodos\anaconda3\lib\site-packages (from pooch>=1.1->librosa==0.10.2.post1) (2.32.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nodos\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa==0.10.2.post1) (2021.10.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nodos\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa==0.10.2.post1) (2.2.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nodos\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa==0.10.2.post1) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nodos\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa==0.10.2.post1) (2.0.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\nodos\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa==0.10.2.post1) (3.5.0)
# Collecting scipy>=1.2.0
#   Using cached scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#   Downloading scipy-1.13.0-cp39-cp39-win_amd64.whl (46.2 MB)
#   Downloading scipy-1.11.4-cp39-cp39-win_amd64.whl (44.3 MB)
# Requirement already satisfied: cffi>=1.0 in c:\users\nodos\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa==0.10.2.post1) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\nodos\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa==0.10.2.post1) (2.21)
# Installing collected packages: numpy, scipy, soxr, soundfile, pooch, lazy-loader, audioread, librosa
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.0
#     Uninstalling numpy-1.24.0:
#       Successfully uninstalled numpy-1.24.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
# Successfully installed audioread-3.0.1 lazy-loader-0.4 librosa-0.10.2.post1 numpy-1.21.6 pooch-1.8.2 scipy-1.11.4 soundfile-0.12.1 soxr-0.5.0.post1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# streamlit 1.24.0 requires importlib-metadata<7,>=1.4, but you have importlib-metadata 8.5.0 which is incompatible.
# streamlit 1.24.0 requires protobuf<5,>=3.20, but you have protobuf 5.28.2 which is incompatible.
# lightautoml 0.3.8.1 requires torch<=2.0.0,>=1.9.0, but you have torch 2.5.1 which is incompatible.
# deeppavlov 1.6.0 requires scikit-learn<1.1.0,>=0.24; python_version <= "3.10", but you have scikit-learn 1.5.2 which is incompatible.
# deeppavlov 1.6.0 requires scipy==1.10.0; python_version >= "3.8", but you have scipy 1.11.4 which is incompatible.
# deeppavlov 1.6.0 requires tqdm<4.65.0,>=4.42.0, but you have tqdm 4.66.2 which is incompatible.
# feature-engine 1.8.1 requires pandas>=2.2.0, but you have pandas 1.4.3 which is incompatible.
# datasets 2.20.0 requires tqdm>=4.66.3, but you have tqdm 4.66.2 which is incompatible.
# dask-expr 1.1.10 requires pandas>=2, but you have pandas 1.4.3 which is incompatible.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement brian2==2.7.1 (from versions: 2.0a0, 2.0a1, 2.0a2, 2.0a3, 2.0a4, 2.0a5, 2.0a6, 2.0a7, 2.0a8, 2.0b2, 2.0b3, 2.0b4, 2.0rc0, 2.0rc1, 2.0rc2, 2.0rc3, 2.0, 2.0.1, 2.0.2, 2.0.2.1, 2.1, 2.1.1, 2.1.2, 2.1.3, 2.1.3.1, 2.2, 2.2.1, 2.2.2, 2.2.2.1, 2.3, 2.3.0.1, 2.3.0.2, 2.4, 2.4.1, 2.4.2, 2.5, 2.5.0.1, 2.5.0.1.post0.dev5, 2.5.0.1.post0.dev6, 2.5.0.2, 2.5.0.3, 2.5.1, 2.5.2, 2.5.3, 2.5.4, 2.6.0)
# ERROR: No matching distribution found for brian2==2.7.1
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# Requirement already satisfied: soundfile==0.12.1 in c:\users\nodos\anaconda3\lib\site-packages (0.12.1)
# Requirement already satisfied: cffi>=1.0 in c:\users\nodos\anaconda3\lib\site-packages (from soundfile==0.12.1) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\nodos\anaconda3\lib\site-packages (from cffi>=1.0->soundfile==0.12.1) (2.21)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement ipython==8.27.0 (from versions: 0.10, 0.10.1, 0.10.2, 0.11, 0.12, 0.12.1, 0.13, 0.13.1, 0.13.2, 1.0.0, 1.1.0, 1.2.0, 1.2.1, 2.0.0, 2.1.0, 2.2.0, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 3.0.0, 3.1.0, 3.2.0, 3.2.1, 3.2.2, 3.2.3, 4.0.0b1, 4.0.0, 4.0.1, 4.0.2, 4.0.3, 4.1.0rc1, 4.1.0rc2, 4.1.0, 4.1.1, 4.1.2, 4.2.0, 4.2.1, 5.0.0b1, 5.0.0b2, 5.0.0b3, 5.0.0b4, 5.0.0rc1, 5.0.0, 5.1.0, 5.2.0, 5.2.1, 5.2.2, 5.3.0, 5.4.0, 5.4.1, 5.5.0, 5.6.0, 5.7.0, 5.8.0, 5.9.0, 5.10.0, 6.0.0rc1, 6.0.0, 6.1.0, 6.2.0, 6.2.1, 6.3.0, 6.3.1, 6.4.0, 6.5.0, 7.0.0b1, 7.0.0rc1, 7.0.0, 7.0.1, 7.1.0, 7.1.1, 7.2.0, 7.3.0, 7.4.0, 7.5.0, 7.6.0, 7.6.1, 7.7.0, 7.8.0, 7.9.0, 7.10.0, 7.10.1, 7.10.2, 7.11.0, 7.11.1, 7.12.0, 7.13.0, 7.14.0, 7.15.0, 7.16.0, 7.16.1, 7.16.2, 7.16.3, 7.17.0, 7.18.0, 7.18.1, 7.19.0, 7.20.0, 7.21.0, 7.22.0, 7.23.0, 7.23.1, 7.24.0, 7.24.1, 7.25.0, 7.26.0, 7.27.0, 7.28.0, 7.29.0, 7.30.0, 7.30.1, 7.31.0, 7.31.1, 7.32.0, 7.33.0, 7.34.0, 8.0.0a1, 8.0.0b1, 8.0.0rc1, 8.0.0, 8.0.1, 8.1.0, 8.1.1, 8.2.0, 8.3.0, 8.4.0, 8.5.0, 8.6.0, 8.7.0, 8.8.0, 8.9.0, 8.10.0, 8.11.0, 8.12.0, 8.12.1, 8.12.2, 8.12.3, 8.13.0, 8.13.1, 8.13.2, 8.14.0, 8.15.0, 8.16.0, 8.16.1, 8.17.0, 8.17.1, 8.17.2, 8.18.0, 8.18.1)
# ERROR: No matching distribution found for ipython==8.27.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nodos\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\nodos\anaconda3\lib\site-packages)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pandas as pd
from brian2 import *
import librosa
import glob
import soundfile as sf
from IPython.display import HTML, display
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, mean_squared_error
from scipy.stats import pearsonr
from sklearn.preprocessing import StandardScaler

from brian2 import prefs
prefs.codegen.target = 'cython'

# Попытка воспроизведения звуков в jupyter-notebook
try:
    import IPython.display as ipd
    from IPython.display import display
    in_notebook = True
except ImportError:
    in_notebook = False

################################################################################
# ПАРАМЕТРЫ СЕТИ И ОБУЧЕНИЯ (без эпох)
################################################################################

num_samples = 50
num_samples_partial = 3  # Число примеров, для которых мониторим детальную активность

tau = 10*ms
dt = 1*ms
defaultclock.dt = dt

eta = 1e-3 * Hz     # Скорость обучения
decay = 1e-2        # Скорость распада
sample_duration_image = 200*ms
sample_duration_audio = 500*ms
sample_duration = max(sample_duration_image, sample_duration_audio)
num_time_steps_per_sample = int(sample_duration / dt)
total_duration = num_samples * sample_duration

N_hidden = 400  # Увеличенный скрытый слой

################################################################################
# ФУНКЦИИ ДЛЯ ЗАГРУЗКИ ДАННЫХ
################################################################################

def load_full_mnist():
    df = pd.read_csv('mnist_784.csv')
    X = df.iloc[:, 0:784].values / 255.0
    y = df.iloc[:, 784].values  
    return X, y

def load_preprocess_audio(num_samples, target_length=5000):
    audio_files = glob.glob('free-spoken-digit-dataset/recordings/*.wav')
    np.random.shuffle(audio_files)
    selected_files = audio_files[:num_samples]
    
    X_audio_list = []
    sr_list = []
    digits_audio = []

    for file in selected_files:
        base_name = file.split('/')[-1]
        digit_str = base_name.split('_')[0]
        audio_digit = int(digit_str)
        digits_audio.append(audio_digit)
        
        signal, sr = librosa.load(file, sr=None)
        sr_list.append(sr)

        if len(signal) > target_length:
            signal = signal[:target_length]
        else:
            signal = np.pad(signal, (0, target_length - len(signal)), 'constant')

        signal = (signal - np.min(signal)) / (np.max(signal) - np.min(signal))
        X_audio_list.append(signal)
    
    X_audio = np.array(X_audio_list)
    sr = sr_list[0] if sr_list else 22050
    
    unique_digits = np.unique(digits_audio)
    if len(unique_digits) < 2 and num_samples > 1:
        raise ValueError("Недостаточно разнообразных классов. Увеличьте количество файлов или перезапустите.")
    
    return X_audio, sr, digits_audio

def match_images_to_audio_digits(X, y, digits_audio, num_samples):
    matched_images = []
    for d in digits_audio:
        indices = np.where(y == d)[0]
        if len(indices) == 0:
            raise ValueError(f"Не найдено изображений в MNIST с цифрой {d}")
        idx = np.random.choice(indices)
        matched_images.append(X[idx])
    matched_images = np.array(matched_images)
    return matched_images

def prepare_input_data(X_image, X_audio, num_time_steps_per_sample):
    num_samples_local = X_image.shape[0]
    N_input_image = X_image.shape[1]
    N_input_audio = X_audio.shape[1]
    
    input_image_array = np.zeros((int(total_duration / dt), N_input_image))
    input_audio_array = np.zeros((int(total_duration / dt), N_input_audio))
    
    for i in range(num_samples_local):
        start_idx = i * num_time_steps_per_sample
        end_idx = (i + 1) * num_time_steps_per_sample
        input_image_array[start_idx:end_idx, :] = X_image[i]
        input_audio_array[start_idx:end_idx, :] = X_audio[i]
    
    Image_ext = TimedArray(input_image_array, dt=dt)
    Audio_ext = TimedArray(input_audio_array, dt=dt)
    
    return Image_ext, Audio_ext
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 6>()
#       4 import matplotlib.animation as animation
#       5 import pandas as pd
# ----> 6 from brian2 import *
#       7 import librosa
#       8 import glob
#
# File ~\anaconda3\lib\site-packages\brian2\__init__.py:91, in <module>
#      87     del rate
#      89 __docformat__ = "restructuredtext en"
# ---> 91 from brian2.only import *
#      92 from brian2.only import test
#      95 # Check for outdated dependency versions
#
# File ~\anaconda3\lib\site-packages\brian2\only.py:28, in <module>
#      26 from brian2.core.functions import *
#      27 from brian2.core.preferences import *
# ---> 28 from brian2.core.clocks import *
#      29 from brian2.equations import *
#      31 # The base class only depends on the above sets
#
# File ~\anaconda3\lib\site-packages\brian2\core\clocks.py:11, in <module>
#       9 from brian2.core.names import Nameable
#      10 from brian2.core.variables import Variables
# ---> 11 from brian2.groups.group import VariableOwner
#      12 from brian2.units.allunits import second
#      13 from brian2.units.fundamentalunits import Quantity, check_units
#
# File ~\anaconda3\lib\site-packages\brian2\groups\__init__.py:5, in <module>
#       1 """
#       2 Package providing groups such as `NeuronGroup` or `PoissonGroup`.
#       3 """
# ----> 5 from .group import *
#       6 from .neurongroup import *
#       7 from .subgroup import *
#
# File ~\anaconda3\lib\site-packages\brian2\groups\group.py:17, in <module>
#      13 from collections.abc import Mapping
#      15 import numpy as np
# ---> 17 from brian2.codegen.codeobject import create_runner_codeobj
#      18 from brian2.core.base import BrianObject, weakproxy_with_fallback
#      19 from brian2.core.functions import Function
#
# File ~\anaconda3\lib\site-packages\brian2\codegen\__init__.py:9, in <module>
#       1 """
#       2 Package providing the code generation framework.
#       3 """
#       5 # Import the runtime packages so that they can register their preferences
#       6
#       7 # isort:skip_file
# ----> 9 from .runtime import *
#      10 from . import _prefs
#      11 from . import cpp_prefs as _cpp_prefs
#
# File ~\anaconda3\lib\site-packages\brian2\codegen\runtime\__init__.py:18, in <module>
#      11 prefs.register_preferences(
#      12     "codegen.runtime",
#      13     "Runtime codegen preferences (see subcategories for individual targets)",
#      14 )
#      16 logger = get_logger(__name__)
# ---> 18 from .numpy_rt import *
#      20 try:
#      21     from .cython_rt import *
#
# File ~\anaconda3\lib\site-packages\brian2\codegen\runtime\numpy_rt\__init__.py:9, in <module>
#       1 """
#       2 Numpy runtime implementation.
#       3
#    (...)
#       6 .. document_brian_prefs:: codegen.runtime.numpy
#       7 """
# ----> 9 from .numpy_rt import *
#
# File ~\anaconda3\lib\site-packages\brian2\codegen\runtime\numpy_rt\numpy_rt.py:20, in <module>
#      12 from brian2.core.preferences import BrianPreference, prefs
#      13 from brian2.core.variables import (
#      14     ArrayVariable,
#      15     AuxiliaryVariable,
#      16     DynamicArrayVariable,
#      17     Subexpression,
#      18 )
# ---> 20 from ...codeobject import CodeObject, check_compiler_kwds, constant_or_scalar
#      21 from ...generators.numpy_generator import NumpyCodeGenerator
#      22 from ...targets import codegen_targets
#
# File ~\anaconda3\lib\site-packages\brian2\codegen\codeobject.py:12, in <module>
#      10 from brian2.core.functions import DEFAULT_FUNCTIONS, Function
#      11 from brian2.core.names import Nameable
# ---> 12 from brian2.equations.unitcheck import check_units_statements
#      13 from brian2.utils.logger import get_logger
#      14 from brian2.utils.stringtools import code_representation, indent
#
# File ~\anaconda3\lib\site-packages\brian2\equations\__init__.py:7, in <module>
#       1 """
#       2 Module handling equations and "code strings", expressions or statements, used
#       3 for example for the reset and threshold definition of a neuron.
#       4 """
#       6 from .codestrings import Expression, Statements
# ----> 7 from .equations import Equations
#       9 __all__ = ["Equations", "Expression", "Statements"]
#
# File ~\anaconda3\lib\site-packages\brian2\equations\equations.py:26, in <module>
#      11 import sympy
#      12 from pyparsing import (
#      13     CharsNotIn,
#      14     Combine,
#    (...)
#      23     restOfLine,
#      24 )
# ---> 26 from brian2.core.namespace import DEFAULT_CONSTANTS, DEFAULT_FUNCTIONS, DEFAULT_UNITS
#      27 from brian2.parsing.sympytools import str_to_sympy, sympy_to_str
#      28 from brian2.units.allunits import second
#
# File ~\anaconda3\lib\site-packages\brian2\core\namespace.py:80, in <module>
#      70     namespace.update(
#      71         {
#      72             name: unit
#    (...)
#      75         }
#      76     )
#      77     return namespace
# ---> 80 DEFAULT_UNITS = _get_default_unit_namespace()
#
# File ~\anaconda3\lib\site-packages\brian2\core\namespace.py:71, in _get_default_unit_namespace()
#      67 namespace.update(stdunits)
#      68 # Include all "simple" units from additional_units, i.e. units like mliter
#      69 # but not "newton * metre"
#      70 namespace.update(
# ---> 71     {
#      72         name: unit
#      73         for name, unit in additional_unit_register.units.items()
#      74         if not unit.iscompound
#      75     }
#      76 )
#      77 return namespace
#
# File ~\anaconda3\lib\site-packages\brian2\core\namespace.py:74, in <dictcomp>(.0)
#      67 namespace.update(stdunits)
#      68 # Include all "simple" units from additional_units, i.e. units like mliter
#      69 # but not "newton * metre"
#      70 namespace.update(
#      71     {
#      72         name: unit
#      73         for name, unit in additional_unit_register.units.items()
# ---> 74         if not unit.iscompound
#      75     }
#      76 )
#      77 return namespace
#
# AttributeError: 'Quantity' object has no attribute 'iscompound'

# %%
################################################################################
# ЗАГРУЗКА ДАННЫХ
################################################################################
X_full, y_full = load_full_mnist()
X_audio, sr, digits_audio = load_preprocess_audio(num_samples=num_samples, target_length=5000)
X_image = match_images_to_audio_digits(X_full, y_full, digits_audio, num_samples=num_samples)
Image_ext, Audio_ext = prepare_input_data(X_image, X_audio, num_time_steps_per_sample)

N_input_image = 784
N_input_audio = X_audio.shape[1]

# %%
################################################################################
# ИНИЦИАЛИЗАЦИЯ СЕТИ
################################################################################

start_scope()

w_input_image_hidden_init = np.random.randn(N_input_image * N_hidden)*0.01
w_input_audio_hidden_init = np.random.randn(N_input_audio * N_hidden)*0.01
w_hidden_image_input_init = np.random.randn(N_hidden * N_input_image)*0.01
w_hidden_audio_input_init = np.random.randn(N_hidden * N_input_audio)*0.01

threshold_value = 'v > 0.5'

input_image_neurons = NeuronGroup(N_input_image, '''
    dv/dt = (-v + V_error) / tau : 1
    V_error = Image_ext(t, i) - v + V_feedback : 1
    V_feedback : 1
    ''',
    threshold=threshold_value, reset='v = 0', method='euler')

input_audio_neurons = NeuronGroup(N_input_audio, '''
    dv/dt = (-v + V_error) / tau : 1
    V_error = Audio_ext(t, i) - v + V_feedback : 1
    V_feedback : 1
    ''',
    threshold=threshold_value, reset='v = 0', method='euler')

hidden_neurons = NeuronGroup(N_hidden, '''
    dv/dt = (-v + V_input_image + V_input_audio) / tau : 1
    V_input_image : 1
    V_input_audio : 1
    ''',
    threshold=threshold_value, reset='v = 0', method='euler')

syn_input_image_hidden = Synapses(input_image_neurons, hidden_neurons, '''
    V_input_image_post = w * v_pre : 1 (summed)
    dw/dt = eta * (v_post * v_pre - w * decay) : 1 (clock-driven)
    ''')
syn_input_image_hidden.connect()
syn_input_image_hidden.w = w_input_image_hidden_init 

syn_input_audio_hidden = Synapses(input_audio_neurons, hidden_neurons, '''
    V_input_audio_post = w * v_pre : 1 (summed)
    dw/dt = eta * (v_post * v_pre - w * decay) : 1 (clock-driven)
    ''')
syn_input_audio_hidden.connect()
syn_input_audio_hidden.w = w_input_audio_hidden_init

syn_hidden_image_input = Synapses(hidden_neurons, input_image_neurons, '''
    V_feedback_post = w * v_pre : 1 (summed)
    dw/dt = eta * (v_post * v_pre - w * decay) : 1 (clock-driven)
    ''')
syn_hidden_image_input.connect()
syn_hidden_image_input.w = w_hidden_image_input_init

syn_hidden_audio_input = Synapses(hidden_neurons, input_audio_neurons, '''
    V_feedback_post = w * v_pre : 1 (summed)
    dw/dt = eta * (v_post * v_pre - w * decay) : 1 (clock-driven)
    ''')
syn_hidden_audio_input.connect()
syn_hidden_audio_input.w = w_hidden_audio_input_init

partial_duration = num_samples_partial * sample_duration
remaining_duration = total_duration - partial_duration

mon_hidden = StateMonitor(hidden_neurons, 'v', record=True)
mon_input_image = StateMonitor(input_image_neurons, 'v', record=True)
mon_input_audio = StateMonitor(input_audio_neurons, 'v', record=True)
spikes_input_image = SpikeMonitor(input_image_neurons)
spikes_input_audio = SpikeMonitor(input_audio_neurons)
spikes_hidden = SpikeMonitor(hidden_neurons)

################################################################################
# ОДНОРАЗОВЫЙ ЗАПУСК СИМУЛЯЦИИ
################################################################################

print("Выполнение симуляции для первых 3 примеров...")
run(partial_duration)

mon_input_image.active = False
mon_input_audio.active = False
spikes_input_image.active = False
spikes_input_audio.active = False
spikes_hidden.active = False

print("Выполнение симуляции для оставшихся примеров...")
run(remaining_duration)

hidden_data_all = mon_hidden.v[:,:]
Выполнение симуляции для первых 3 примеров...
INFO       No numerical integration method specified for group 'synapses_1', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
INFO       No numerical integration method specified for group 'synapses_3', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
INFO       No numerical integration method specified for group 'synapses_4', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
INFO       No numerical integration method specified for group 'synapses', using method 'exact' (took 0.00s). [brian2.stateupdaters.base.method_choice]
Выполнение симуляции для оставшихся примеров...
def animate_reconstruction_image(sample_index):
    start_time = sample_index * sample_duration
    end_time = (sample_index + 1) * sample_duration
    start_idx = int(start_time / dt)
    end_idx = int(end_time / dt)
    
    fig = plt.figure()
    plt.axis('off')
    ims = []
    
    for t in range(start_idx, end_idx):
        reconstructed_img = mon_input_image.v[:, t]
        im = plt.imshow(reconstructed_img.reshape(28,28), cmap='gray', animated=True)
        ims.append([im])
    
    ani = animation.ArtistAnimation(fig, ims, interval=300, blit=True, repeat_delay=1000)
    ani.save(f'animation_sample{sample_index}.gif')
    plt.title(f'Реконструкция образца изображения {sample_index} по времени')
    plt.close(fig)
    display(HTML(ani.to_jshtml()))

def animate_reconstruction_audio(sample_index):
    start_time = sample_index * sample_duration
    end_time = (sample_index + 1) * sample_duration
    start_idx = int(start_time / dt)
    end_idx = int(end_time / dt)
    
    reconstructed_signal = mon_input_audio.v[:, start_idx:end_idx].mean(axis=1)
    original_signal = X_audio[sample_index]
    
    plt.figure(figsize=(12, 6))
    plt.plot(original_signal, label='Original Signal')
    plt.plot(reconstructed_signal, label='Reconstructed Signal')
    plt.legend()
    plt.title(f'Реконструкция аудиообразца {sample_index}')
    plt.xlabel('Время')
    plt.ylabel('Амплитуда')
    plt.show()
    
    sf.write(f'original_signal_sample{sample_index}.wav', original_signal, sr)
    sf.write(f'reconstructed_signal_sample{sample_index}.wav', reconstructed_signal, sr)
    
    if in_notebook:
        print("Оригинальный сигнал:")
        display(ipd.Audio(original_signal, rate=sr))
        print("Реконструированный сигнал:")
        display(ipd.Audio(reconstructed_signal, rate=sr))

def plot_spikes(spike_monitor, layer_name):
    plt.figure(figsize=(12, 6))
    plt.plot(spike_monitor.t/ms, spike_monitor.i, '|')
    plt.title(f'Спайковая активность в {layer_name}')
    plt.xlabel('Время (мсек)')
    plt.ylabel('Индекс нейрона')
    plt.show()

for idx in range(num_samples_partial):
    print(f'\nАнимационная реконструкция для образца изображения {idx}, цифра: {digits_audio[idx]}')
    animate_reconstruction_image(idx)
    print(f'\nАнимационная реконструкция для аудиосэмпла {idx}, цифра: {digits_audio[idx]}')
    animate_reconstruction_audio(idx)

plot_spikes(spikes_input_image, 'Входной слой с изображениями')
plot_spikes(spikes_input_audio, 'Входной аудиовход')
plot_spikes(spikes_hidden, 'Скрытый слой')
Анимационная реконструкция для образца изображения 0, цифра: 9
No description has been provided for this image

        
 Once  Loop  Reflect
Анимационная реконструкция для аудиосэмпла 0, цифра: 9
No description has been provided for this image
Оригинальный сигнал:
Реконструированный сигнал:
Анимационная реконструкция для образца изображения 1, цифра: 6
No description has been provided for this image

        
 Once  Loop  Reflect
Анимационная реконструкция для аудиосэмпла 1, цифра: 6
No description has been provided for this image
Оригинальный сигнал:
Реконструированный сигнал:
Анимационная реконструкция для образца изображения 2, цифра: 9
No description has been provided for this image

        
 Once  Loop  Reflect
Анимационная реконструкция для аудиосэмпла 2, цифра: 9
No description has been provided for this image
Оригинальный сигнал:
Реконструированный сигнал:
No description has been provided for this image
No description has been provided for this image
No description has been provided for this image
###############################################################################
# КЛАССИЧЕСКАЯ КЛАССИФИКАЦИЯ MNIST ДЛЯ СРАВНЕНИЯ
###############################################################################

X_train_full, X_test_full, y_train_full, y_test_full = train_test_split(X_full, y_full, test_size=0.2, random_state=42)
clf_classic = LogisticRegression(max_iter=1000)
clf_classic.fit(X_train_full, y_train_full)
y_pred_classic = clf_classic.predict(X_test_full)
classic_accuracy = accuracy_score(y_test_full, y_pred_classic)

###############################################################################
# КЛАССИФИКАЦИЯ ПО АКТИВНОСТИ СКРЫТОГО СЛОЯ
###############################################################################

hidden_activity = []
for idx in range(num_samples):
    start_idx = idx * num_time_steps_per_sample
    end_idx = (idx + 1) * num_time_steps_per_sample
    mean_activity = np.mean(mon_hidden.v[:, start_idx:end_idx], axis=1)
    hidden_activity.append(mean_activity)

hidden_activity = np.array(hidden_activity)
y_labels = np.array(digits_audio)

print("Размер данных до очистки:", hidden_activity.shape, len(y_labels))
print("Проверка NaN в hidden_activity:", np.isnan(hidden_activity).any())
print("Проверка NaN в y_labels:", np.isnan(y_labels).any())

mask = ~np.isnan(hidden_activity).any(axis=1)
hidden_activity_clean = hidden_activity[mask]
y_labels_clean = y_labels[mask]

# Нормируем данные скрытого слоя для повышения устойчивости классификатора
scaler = StandardScaler()
hidden_activity_scaled = scaler.fit_transform(hidden_activity_clean)

if len(np.unique(y_labels_clean)) > 1:
    X_train_h, X_test_h, y_train_h, y_test_h = train_test_split(hidden_activity_scaled, y_labels_clean, test_size=0.5, random_state=42)
    clf_hidden = LogisticRegression(max_iter=1000)
    clf_hidden.fit(X_train_h, y_train_h)
    y_pred_hidden = clf_hidden.predict(X_test_h)
    hidden_accuracy = accuracy_score(y_test_h, y_pred_hidden)
else:
    hidden_accuracy = 0.0

###############################################################################
# ОЦЕНКА РЕКОНСТРУКЦИИ
###############################################################################

def evaluate_reconstruction_image(sample_index):
    start_time = sample_index * sample_duration
    end_time = (sample_index + 1) * sample_duration
    start_idx = int(start_time / dt)
    end_idx = int(end_time / dt)
    original_img = X_image[sample_index]
    reconstructed_img = mon_input_image.v[:, end_idx-1]
    mse_img = mean_squared_error(original_img, reconstructed_img)
    corr_img, _ = pearsonr(original_img, reconstructed_img)
    print(f"Оценка реконструкции изображения для сэмпла {sample_index}: MSE={mse_img}, Корреляция={corr_img}")

def evaluate_reconstruction_audio(sample_index):
    start_time = sample_index * sample_duration
    end_time = (sample_index + 1) * sample_duration
    start_idx = int(start_time / dt)
    end_idx = int(end_time / dt)
    original_signal = X_audio[sample_index]
    reconstructed_signal = mon_input_audio.v[:, start_idx:end_idx].mean(axis=1)
    mse_audio = mean_squared_error(original_signal, reconstructed_signal)
    corr_audio, _ = pearsonr(original_signal, reconstructed_signal)
    print(f"Оценка реконструкции аудио для сэмпла {sample_index}: MSE={mse_audio}, Корреляция={corr_audio}")

for idx in range(num_samples_partial):
    evaluate_reconstruction_image(idx)
    evaluate_reconstruction_audio(idx)

###############################################################################
# ИТОГОВЫЕ РЕЗУЛЬТАТЫ
###############################################################################

print("----- Итоговые результаты -----")
print("Классический метод (логистическая регрессия по пикселям MNIST):", classic_accuracy)
print("Спайковая модель (логрега по скрытому слою):", hidden_accuracy)
Проверка NaN в данных скрытого слоя: True
Размер данных до очистки: (50, 400) 50
Проверка NaN в hidden_activity: True
Проверка NaN в y_labels: False
Оценка реконструкции изображения для сэмпла 0: MSE=0.07448555193012676, Корреляция=0.927284909842296
Оценка реконструкции аудио для сэмпла 0: MSE=0.11763602699229735, Корреляция=0.8935992515549073
Оценка реконструкции изображения для сэмпла 1: MSE=0.030246157835771368, Корреляция=0.9375535496166726
Оценка реконструкции аудио для сэмпла 1: MSE=0.08395155598810614, Корреляция=0.6331464970066376
Оценка реконструкции изображения для сэмпла 2: MSE=0.033598291726596397, Корреляция=0.9071031483514792
Оценка реконструкции аудио для сэмпла 2: MSE=0.0913591422584717, Корреляция=0.7128568591864987
----- Итоговые результаты -----
Классический метод (логистическая регрессия по пикселям MNIST): 0.9203571428571429
Спайковая модель (логрега по скрытому слою): 0.3333333333333333
См. метрики MSE и корреляции выше для оценки качества реконструкции.
